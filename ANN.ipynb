# %% [markdown]
# #                                                # ANN

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("Customer_info.csv")
df
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# # Feature Selection

# %%
# we are excluding RowNumber , CustomerId, and Surname as they are not needed.
x = df.iloc[:, 3:-1]
y = df.iloc[:,13]

# %%
x.head(10)
# Out:
#    CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0          619    France  Female   42       2       0.00              1
# 1          608     Spain  Female   41       1   83807.86              1
# 2          502    France  Female   42       8  159660.80              3
# 3          699    France  Female   39       1       0.00              2
# 4          850     Spain  Female   43       2  125510.82              1
# 5          645     Spain    Male   44       8  113755.78              2
# 6          822    France    Male   50       7       0.00              2
# 7          376   Germany  Female   29       4  115046.74              4
# 8          501    France    Male   44       4  142051.07              2
# 9          684    France    Male   27       2  134603.88              1
#
#    HasCrCard  IsActiveMember  EstimatedSalary
# 0          1               1        101348.88
# 1          0               1        112542.58
# ...

# %%
print(x['Geography'].unique())
# Out:
# ['France' 'Spain' 'Germany']

# %% [markdown]
# # Creating dummies variable for Geography and Gender

# %%
Geog = pd.get_dummies(x['Geography'],drop_first=True)
Gen = pd.get_dummies(x['Gender'],drop_first=True)

# %%
# adding the dummies column to x
x = pd.concat([x,Geog,Gen], axis=1)

# %%
#dropping the catagorical features
x = x.drop(["Geography","Gender"], axis=1)

# %%
x.head()
# Out:
#    CreditScore  Age  Tenure    Balance  NumOfProducts  HasCrCard  \
# 0          619   42       2       0.00              1          1
# 1          608   41       1   83807.86              1          0
# 2          502   42       8  159660.80              3          1
# 3          699   39       1       0.00              2          0
# 4          850   43       2  125510.82              1          1
#
#    IsActiveMember  EstimatedSalary  Germany  Spain  Male
# 0               1        101348.88        0      0     0
# 1               1        112542.58        0      1     0
# 2               0        113931.57        0      0     0
# 3               0         93826.63        0      0     0
# 4               1         79084.10        0      1     0

# %%
#splitting the data into training and testing
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=0)

# %%
# feature scaling to bring features into same scale range.
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.fit_transform(X_test)

# %% [markdown]
# # Implementing ANN(Artificial Nural Network)

# %%
# Importing the Keras libraries and packages
import keras
from keras.models import Sequential  #
from keras.layers import Dense       # for creating hidden leayers
from keras.layers import LeakyReLU,PReLU,ELU #
from keras.layers import Dropout # using for regularization

# %%
model = Sequential()

#first hidden layer
model.add(Dense(10, activation='relu', input_dim=11)) # input dim = number of features 

#second hidden layer
model.add(Dense(12, activation='relu'))


#second hidden layer
model.add(Dense(15, activation='relu'))

#Output layer
model.add(Dense(1,activation='sigmoid'))

# Havnt used drop out becuse we dont have deep dense layers. In our case it might reduce the accuracy

# %%
model.summary()
# Out:
# Model: "sequential_16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_33 (Dense)             (None, 10)                120
# _________________________________________________________________
# dense_34 (Dense)             (None, 12)                132
# _________________________________________________________________
# dense_35 (Dense)             (None, 15)                195
# _________________________________________________________________
# dense_36 (Dense)             (None, 1)                 16
# ...
# Total params: 463
# Trainable params: 463
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Compiling the ANN ( using optimizer and Loss function)

# %%
model.compile(optimizer="Adam", loss="binary_crossentropy", metrics=['accuracy'])

# %%
# Training the data
model_train = model.fit(X_train,y_train,validation_split=0.33,batch_size=10,epochs=100)
# Out:
# Epoch 1/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4886 - accuracy: 0.7960 - val_loss: 0.4539 - val_accuracy: 0.7982
# Epoch 2/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4375 - accuracy: 0.8044 - val_loss: 0.4438 - val_accuracy: 0.7989
# Epoch 3/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4223 - accuracy: 0.8179 - val_loss: 0.4366 - val_accuracy: 0.8039
# Epoch 4/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4141 - accuracy: 0.8203 - val_loss: 0.4284 - val_accuracy: 0.8114
# Epoch 5/100
# 536/536 [==============================] - 1s 2ms/step - loss: 0.4033 - accuracy: 0.8280 - val_loss: 0.4195 - val_accuracy: 0.8156
# Epoch 6/100
# 536/536 [==============================] - 2s 3ms/step - loss: 0.3868 - accuracy: 0.8403 - val_loss: 0.4000 - val_accuracy: 0.8285
# Epoch 7/100
# ...

# %%
print(model_train.history.keys())
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# # Predicting test Result

# %%
y_pred = model.predict(X_test)

# converting the 0 and 1 into true or fale 
y_pred = (y_pred > 0.5)

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)

# %%
cm
# Out:
# array([[1514,   81],
#        [ 214,  191]], dtype=int64)

# %%
# Calculate the Accuracy
from sklearn.metrics import accuracy_score
score=accuracy_score(y_pred,y_test)
score
# Out:
# 0.8525
